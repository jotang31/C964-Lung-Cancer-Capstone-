# %% [markdown]
# # C964 Computer Science Capstone

# %% [markdown]
# ## Lung Cancer Prediction

# %% [markdown]
# ### Joanna Tang

# %% [markdown]
# ## Our dataset: survey lung cancer.csv

# %%
import pandas as pd

# Import the data into a DataFrame
url = "survey lung cancer.csv"
df = pd.read_csv(url)
df
# Out:
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# ...

# %% [markdown]
# ### In the pool of people sampled for the data set, 270 of the 309 persons had lung cancer.

# %%
# Find how many are in each category.
num_types = df.groupby(by='LUNG_CANCER').size()
print(num_types)
print(type(num_types))
# Out:
# LUNG_CANCER
# NO      39
# YES    270
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
num_types.plot.bar(color=['red','blue','green'],rot=0)
# Out:
# <Axes: xlabel='LUNG_CANCER'>

# %%
# since the lung_cancer is not evenly distributed, show on a pie chart!
df.groupby('LUNG_CANCER').size().plot(kind='pie',colors = ['lightblue', 'orange', 'limegreen']);

# %%
num_ages = df.groupby(by='AGE').size()
print(num_ages)
hist_age = df['AGE'].hist(grid = False, bins = 20)
# Out:
# AGE
# 21     1
# 38     1
# 39     1
# 44     2
# 46     1
# 47     4
# 48     2
# 49     3
# 51     8
# 52     4
# 53     4
# 54     8
# 55    11
# 56    19
# 57     9
# 58    13
# 59    15
# 60    17
# 61    16
# 62    18
# 63    19
# 64    20
# 65     7
# 66     4
# 67    13
# 68     9
# 69    11
# 70    15
# 71    10
# 72    10
# 73     4
# 74     6
# 75     5
# 76     4
# 77     9
# 78     2
# 79     1
# 81     2
# 87     1
# dtype: int64

# %% [markdown]
# ### As we can see from the histogram plot of ages, the majority of the persons used for this data set were in their mid-50's to mid-70's.
# ### Below, we see the information for the 19 people who were of age 63.

# %%
print(type(df['AGE'])) # a Series
print("Row count: ", len(df[df['AGE'] == 63])) # 19 rows
df[df['AGE'] == 63]
# df[df['AGE'] == 21]
# Out:
# <class 'pandas.core.series.Series'>
# Row count:  19
#     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# 41       M   63        1               1        1              2
# 51       M   63        2               2        2              1
# 56       F   63        1               2        1              2
# 129      F   63        1               1        1              1
# 139      M   63        1               2        1              1
# 143      F   63        2               2        2              2
# 165      M   63        1               2        2              1
# 180      M   63        2               2        2              2
# 194      M   63        1               1        1              1
# 200      F   63        1               1        1              2
# 207      M   63        2               1        1              2
# ...

# %% [markdown]
# ### Below, we see the age distribution of the people in our sample who had lung cancer (red) and who did not have lung cancer (purple-ish blue).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

A = df[df['LUNG_CANCER'] == 'YES']['AGE']
B = df[df['LUNG_CANCER'] == 'NO']['AGE']

#C = df[df['GENDER'] == 'F']['LUNG_CANCER']
#D = df[df['GENDER'] == 'M']['LUNG_CANCER']

sns.histplot(A, color = 'red', kde=True, bins = 10)
sns.histplot(B, color ='blue', kde=True, bins = 10)
#sns.histplot(C, color = 'green', kde=True, bins = 10)
#sns.histplot(D, color = 'yellow', kde=True, bins = 10)
plt.show()

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ### Below, we split the data into independent variables (X) and dependent variables (y). We also do some preprocessing on the column 'GENDER' using Panda's get_dummies() function to change the categorical data ('M' and 'F') into numerical data. This is important because most machine learning models only work with numerical data.

# %%
X = df.drop(columns=['LUNG_CANCER']) #indpendent variables
y = df[['LUNG_CANCER']].copy() #dependent variables

X_after_get_dummies = pd.get_dummies(X, columns=['GENDER'])
X_after_get_dummies
#X_after_get_dummies.columns
# Out:
#      AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  CHRONIC DISEASE  \
# 0     69        1               2        2              1                1
# 1     74        2               1        1              1                2
# 2     59        1               1        1              2                1
# 3     63        2               2        2              1                1
# 4     63        1               2        1              1                1
# ..   ...      ...             ...      ...            ...              ...
# 304   56        1               1        1              2                2
# 305   70        2               1        1              1                1
# 306   58        2               1        1              1                1
# 307   67        2               1        2              1                1
# 308   62        1               1        1              2                1
#
#      FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# ...

# %% [markdown]
# ### Now we are ready to split the dataset into 2 parts, one part for training the model and one part for testing the model. Here we choose to reserve 30% of the data for testing. The other 70% will be used for training. Note, the testing data and training data are further split to designate their independent and dependent variables (X and y).

# %%
import numpy as np
from sklearn.model_selection import train_test_split

#split the variable sets into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X_after_get_dummies, y, test_size=0.3, random_state=12)

# %% [markdown]
# ### Here is a nice display of the split between the independent variables and our dependent variable for lung cancer.

# %%
#Nice displays are nice but not required. 
from IPython.display import display_html 
X_train_styler = X_train.head(7).style.set_table_attributes("style='display:inline'").set_caption('Independents variables')
y_train_styler = y_train.head(7).style.set_table_attributes("style='display:inline'").set_caption('Dependents variables')
space = "\xa0" * 10 #space between columns
display_html(X_train_styler._repr_html_()+ space  + y_train_styler._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d2d2" style='display:inline'>
#   <caption>Independents variables</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d2d2_level0_col0" class="col_heading level0 col0" >AGE</th>
#       <th id="T_0d2d2_level0_col1" class="col_heading level0 col1" >SMOKING</th>
#       <th id="T_0d2d2_level0_col2" class="col_heading level0 col2" >YELLOW_FINGERS</th>
#       <th id="T_0d2d2_level0_col3" class="col_heading level0 col3" >ANXIETY</th>
#       <th id="T_0d2d2_level0_col4" class="col_heading level0 col4" >PEER_PRESSURE</th>
#       <th id="T_0d2d2_level0_col5" class="col_heading level0 col5" >CHRONIC DISEASE</th>
#       <th id="T_0d2d2_level0_col6" class="col_heading level0 col6" >FATIGUE </th>
#       <th id="T_0d2d2_level0_col7" class="col_heading level0 col7" >ALLERGY </th>
#       <th id="T_0d2d2_level0_col8" class="col_heading level0 col8" >WHEEZING</th>
# ...

# %%
from sklearn import svm, metrics

# SVM Model
svm_model = svm.SVC(gamma='scale', C=1) #Creates a svm model object. Mote, 'scale' and 1.0 are gamma and C's respective defaults 
y_train_array = np.ravel(y_train.values) # Convert the DataFrame into an array to silence warning.
svm_model.fit(X_train,y_train_array) # Train the model

#Using test data
predictions = svm_model.predict(X_test)
score = metrics.accuracy_score(y_test, predictions)
print("first model: ", score)
#90

#Using train data
#predictions = svm_model.predict(X_train)
#score = metrics.accuracy_score(y_train, predictions)
#score
#86 - oh no, it's worse...odd. Normally, we would get better results if we predict using training data because the model has already seen it.

#see the confusion matrix breakdown (makes 93 predictions)
cm = metrics.confusion_matrix(y_test, predictions, labels=svm_model.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=svm_model.classes_)
disp.plot();
#results: it predicted YES 93 times. Reality: there are 9 NOs and 84 YESs
#a confusion matrix is used for classification models and 
#it describes the performance of a classificaiton madel on test data for which true values are known.


# Let's train using cross-validation
from sklearn.model_selection import KFold, cross_val_score
# Our 'y' is a dataframe but this functions requires the indepenent variables ot be a 1d array.
y_array = np.ravel(y.values)

k_folds = KFold(n_splits = 5, shuffle=True)
# The number of folds determines the test/train split for each iteration. 
# So 5 folds has 5 different mutually exclusive training sets. 
# That's a 1 to 4 (or .20 to .80) testing/training split for each of the 5 iterations.

svm_model_2 = svm.SVC(C=1, random_state = 42) #Creates another svm model object.
scores = cross_val_score(svm_model_2, X_after_get_dummies, y_array)
# This shows the average score. Print 'scores' to see an array of individual iteration scores.
print("Average Score: ", scores.mean())
#87 better than test data

# Logistic Regression Model - let's try and see how the prediction accuracy compares with the SVM model.
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression(random_state=0).fit(X_train, y_train_array)
predictions_log = log_model.predict(X_test)
score_log = metrics.accuracy_score(y_test, predictions_log)
print("score_log: ", score_log)
#94.6 Wow

#see the confusion matrix breakdown for logistic regression (makes 93 predictions)
cm_log = metrics.confusion_matrix(y_test, predictions_log, labels=svm_model.classes_)
disp_log = metrics.ConfusionMatrixDisplay(confusion_matrix=cm_log, display_labels=svm_model.classes_)
disp_log.plot();
#results: it predicted YES 85 times, 82 were true positives. 
# Out of 93 predictions, 88 were correct.
# Out:
# first model:  0.9032258064516129
# Average Score:  0.873823373876256
# score_log:  0.946236559139785
# C:\Users\Jo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print(predictions_log)
# Out:
# ['YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'NO' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO'
#  'YES' 'YES' 'YES' 'YES' 'NO' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'NO' 'YES'
#  'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES' 'YES']

# %% [markdown]
# # User Interface

# %% [markdown]
# ### Version 1 (the 'meh' version)

# %%
# Your chances of having lung cancer.
gender = input("What is your gender? (enter M for male and F for female) ")

# assume gender == 'F'
genderf = 1
genderm = 0
if gender == 'M':
    genderf = 0
    genderm = 1
    
age = input("How old are you? ")
smoking = input("Do you smoke?(enter 2 for YES, 1 for NO) ")
yellow_fingers = input("Do you experience yellow fingers?(enter 2 for YES, 1 for NO) ")
anxiety = input("Do you experience anxiety?(enter 2 for YES, 1 for NO) ")
peer_pressure = input("Do you experience peer pressure?(enter 2 for YES, 1 for NO) ")
chronic_disease = input("Do you have a chronic disease?(enter 2 for YES, 1 for NO) ")
fatigue = input("Do you experience fatigue?(enter 2 for YES, 1 for NO) ")
allergy = input("Do you have allergies?(enter 2 for YES, 1 for NO) ")
wheezing = input("Do you experience wheezing?(enter 2 for YES, 1 for NO) ")
alcohol = input("Do you consume alcohol?(enter 2 for YES, 1 for NO) ")
cough = input("Do you have coughs?(enter 2 for YES, 1 for NO) ")
shortness_of_breath = input("Do you experience shortness of breath?(enter 2 for YES, 1 for NO) ")
swallowing_diff = input("Do you experience swallowing difficulty?(enter 2 for YES, 1 for NO) ")
chest_pain = input("Do you have chest pain?(enter 2 for YES, 1 for NO) ")

#make a data frame of these answers
results = [[age, smoking, yellow_fingers, anxiety, peer_pressure, chronic_disease, fatigue, allergy, wheezing, alcohol, cough, shortness_of_breath, swallowing_diff, chest_pain, genderf, genderm]]
df_users_results = pd.DataFrame(results, columns=X_after_get_dummies.columns)
prediction_for_user = log_model.predict(df_users_results)
print("\nUsing our model that predicts correctly 94.6% of the "+ 
      "time \n(predicting true negatives with 75% accuracy \n"+
      "and true positives with 96.5% accuracy), \nour " +
      "non-professional diagnosis that you have lung cancer is ")
print(prediction_for_user)
# Out:
# What is your gender? (enter M for male and F for female) M
# How old are you? 67
# Do you smoke?(enter 2 for YES, 1 for NO) 2
# Do you experience yellow fingers?(enter 2 for YES, 1 for NO) 2
# Do you experience anxiety?(enter 2 for YES, 1 for NO) 2
# Do you experience peer pressure?(enter 2 for YES, 1 for NO) 2
# Do you have a chronic disease?(enter 2 for YES, 1 for NO) 2
# Do you experience fatigue?(enter 2 for YES, 1 for NO) 2
# Do you have allergies?(enter 2 for YES, 1 for NO) 2
# Do you experience wheezing?(enter 2 for YES, 1 for NO) 2
# Do you consume alcohol?(enter 2 for YES, 1 for NO) 2
# Do you have coughs?(enter 2 for YES, 1 for NO) 2
# Do you experience shortness of breath?(enter 2 for YES, 1 for NO) 2
# Do you experience swallowing difficulty?(enter 2 for YES, 1 for NO) 2
# Do you have chest pain?(enter 2 for YES, 1 for NO) 2
#
# Using our model that predicts correctly 94.6% of the time
# (predicting true negatives with 75% accuracy
# ...

# %% [markdown]
# ### Version 2 (the widget version)

# %%
from IPython.display import display
import ipywidgets as widgets

print("Please check all that apply to you")

c = widgets.Checkbox(description='smoking', indent=False)
d = widgets.Checkbox(description='yellow fingers', indent=False)
e = widgets.Checkbox(description='anxiety', indent=False)
f = widgets.Checkbox(description='peer pressure', indent=False)
g = widgets.Checkbox(description='chronic disease', indent=False)
h = widgets.Checkbox(description='fatigue', indent=False)
i = widgets.Checkbox(description='allergies', indent=False)
j = widgets.Checkbox(description='wheezing', indent=False)
k = widgets.Checkbox(description='alcohol consumption', indent=False)
l = widgets.Checkbox(description='coughs', indent=False)
m = widgets.Checkbox(description='shortness of breath', indent=False)
n = widgets.Checkbox(description='swallowing difficulty', indent=False)
o = widgets.Checkbox(description='chest pain', indent=False)

a = widgets.Dropdown(options=[('Male', 'M'), ('Female', 'F')], description='Gender ')
b = widgets.IntSlider(description = "Your age")
display(c,d,e,f,g,h,i,j,k,l,m,n,o, b, a)


def clicked(arg):
        
    age = b.value
    
    # assume gender == 'F'
    genderf = 1
    genderm = 0
    if a.value == 'M':
        genderf = 0
        genderm = 1
        
    smoking = 1
    if c.value == True:
        smoking = 2
        
    yellow_fingers = 1
    if d.value == True:
        yellow_fingers = 2
    
    anxiety = 1
    if e.value == True:
        anxiety = 2
        
    peer_pressure = 1
    if f.value == True:
        peer_pressure = 2
        
    chronic_disease = 1
    if g.value == True:
        chronic_disease = 2
        
    fatigue = 1
    if h.value == True:
        fatigue = 2
        
    allergy = 1
    if i.value == True:
        allergy = 2
    
    wheezing = 1
    if j.value == True:
        wheezing = 2
    
    alcohol = 1
    if k.value == True:
        alcohol = 2
        
    cough = 1
    if l.value == True:
        cough = 2
        
    shortness_of_breath = 1
    if m.value == True:
        shortness_of_breath = 2
        
    swallowing_diff = 1
    if n.value == True:
        swallowing_diff = 2
        
    chest_pain = 1
    if o.value == True:
        chest_pain = 2
    
    results = [[age, smoking, yellow_fingers, anxiety, peer_pressure, chronic_disease, fatigue, allergy, wheezing, alcohol, cough, shortness_of_breath, swallowing_diff, chest_pain, genderf, genderm]]
    df_users_results = pd.DataFrame(results, columns=X_after_get_dummies.columns)
    prediction_for_user = log_model.predict(df_users_results)
    print("\nUsing our model that predicts correctly 94.6% of the "+ 
          "time \n(predicting true negatives with 75% accuracy \n"+
          "and true positives with 96.5% accuracy), \nour " +
          "non-professional diagnosis that you have lung cancer is ")
    print(prediction_for_user)
        

button_download = widgets.Button(description = 'Apply')   
button_download.on_click(clicked)
display(button_download)
# Out:
# Please check all that apply to you
# Checkbox(value=False, description='smoking', indent=False)
# Checkbox(value=False, description='yellow fingers', indent=False)
# Checkbox(value=False, description='anxiety', indent=False)
# Checkbox(value=False, description='peer pressure', indent=False)
# Checkbox(value=False, description='chronic disease', indent=False)
# Checkbox(value=False, description='fatigue', indent=False)
# Checkbox(value=False, description='allergies', indent=False)
# Checkbox(value=False, description='wheezing', indent=False)
# Checkbox(value=False, description='alcohol consumption', indent=False)
# Checkbox(value=False, description='coughs', indent=False)
# Checkbox(value=False, description='shortness of breath', indent=False)
# Checkbox(value=False, description='swallowing difficulty', indent=False)
# Checkbox(value=False, description='chest pain', indent=False)
# IntSlider(value=0, description='Your age')
# ...
